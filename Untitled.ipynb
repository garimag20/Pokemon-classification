# %%
import os
from pathlib import Path
from keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
p = Path("./dataset/")
dirs= p.glob("*")

# %%
image_data = []
labels = []

labels_dic = {"Pikachu" : 0, "Bulbasaur" : 1, "Meowth" : 2}

for folder_dir in dirs:
    label = str(folder_dir).split("\\")[-1]
    
    cnt = 0
    print(folder_dir)
    
    #iterate through folder_dir and pick all images of pokemon
    for img_path in folder_dir.glob("*.jpg"):
        img = image.load_img(img_path, target_size = (100,100))
        img_array = image.img_to_array(img)
        
        image_data.append(img_array)
        labels.append(labels_dic[label])
        
        cnt += 1
        
    print(cnt)
# Out:
# dataset\Bulbasaur
# 176
# dataset\Meowth
# 70
# dataset\Pikachu
# 199

# %% [markdown]
# ### Visualisation

# %%
import numpy as np

# %%
X = np.array(image_data)
Y = np.array(labels)

# %%
print(X.shape, Y.shape)
# Out:
# (445, 100, 100, 3) (445,)

# %%
#Draw some pokemons
def drawImage(img, label):
    plt.imshow(img)
    plt.show()

# %%
for i in range(10):
    r = np.random.randint(400)
    drawImage(X[r]/255.0, Y[r])
